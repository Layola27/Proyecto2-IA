# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importando la biblioteca pandas para manipulación y análisis de datos
import pandas as pd
business_payments = pd.read_csv('drive/MyDrive/ColabNotebooks/Business_Payments/merged_inner.csv')

# %%
business_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21057 entries, 0 to 21056
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          21057 non-null  int64
#  1   cash_request_id             21057 non-null  float64
#  2   type                        21057 non-null  object
#  3   status                      21057 non-null  object
#  4   category                    2196 non-null   object
#  5   total_amount                21057 non-null  float64
#  6   reason                      21057 non-null  object
#  7   created_at                  21057 non-null  object
#  8   updated_at                  21057 non-null  object
#  9   paid_at                     15531 non-null  object
#  10  from_date                   7766 non-null   object
#  11  to_date                     7766 non-null   object
#  12  charge_moment               21057 non-null  object
#  13  amount                      21057 non-null  float64
#  14  cash_request_status         21057 non-null  object
#  15  cash_request_created_at     21057 non-null  object
#  16  cash_request_updated_at     21057 non-null  object
#  17  user_id                     20151 non-null  float64
#  18  moderated_at                11284 non-null  object
#  19  deleted_account_id          906 non-null    float64
#  20  reimbursement_date          21057 non-null  object
#  21  cash_request_received_date  19763 non-null  object
#  22  money_back_date             19701 non-null  object
#  23  transfer_type               21057 non-null  object
#  24  send_at                     17570 non-null  object
#  25  recovery_status             6894 non-null   object
#  26  reco_creation               6894 non-null   object
#  27  reco_last_update            6894 non-null   object
# dtypes: float64(5), int64(1), object(22)
# memory usage: 4.5+ MB

# %%
# Convertir columnas de fechas a datetime
date_columns = [
    'created_at', 'updated_at', 'paid_at', 'from_date', 'to_date',
    'cash_request_created_at', 'cash_request_updated_at', 'moderated_at',
    'reimbursement_date', 'cash_request_received_date', 'money_back_date',
    'send_at', 'reco_creation', 'reco_last_update'
]

for col in date_columns:
    if col in business_payments.columns:
        business_payments[col] = pd.to_datetime(business_payments[col], errors='coerce')

# Convertir identificadores a int (si no tienen valores faltantes)
id_columns = ['id', 'cash_request_id', 'user_id']

for col in id_columns:
    if col in business_payments.columns:
        # Verificar si la columna contiene valores faltantes
        if business_payments[col].isnull().any():
            print(f"La columna {col} tiene valores faltantes, no se convertirá a int.")
        else:
            business_payments[col] = business_payments[col].astype(int)

# Confirmar las conversiones
print(business_payments.dtypes)
# Out:
# La columna user_id tiene valores faltantes, no se convertirá a int.
# id                                          int64
# cash_request_id                             int64
# type                                       object
# status                                     object
# category                                   object
# total_amount                              float64
# reason                                     object
# created_at                    datetime64[ns, UTC]
# updated_at                    datetime64[ns, UTC]
# paid_at                       datetime64[ns, UTC]
# from_date                     datetime64[ns, UTC]
# to_date                       datetime64[ns, UTC]
# charge_moment                              object
# amount                                    float64
# cash_request_status                        object
# cash_request_created_at       datetime64[ns, UTC]
# cash_request_updated_at       datetime64[ns, UTC]
# user_id                                   float64
# moderated_at                  datetime64[ns, UTC]
# deleted_account_id                        float64
# reimbursement_date            datetime64[ns, UTC]
# cash_request_received_date         datetime64[ns]
# money_back_date               datetime64[ns, UTC]
# transfer_type                              object
# send_at                       datetime64[ns, UTC]
# recovery_status                            object
# reco_creation                 datetime64[ns, UTC]
# reco_last_update              datetime64[ns, UTC]
# dtype: object

# %%
business_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21057 entries, 0 to 21056
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          21057 non-null  int64
#  1   cash_request_id             21057 non-null  int64
#  2   type                        21057 non-null  object
#  3   status                      21057 non-null  object
#  4   category                    2196 non-null   object
#  5   total_amount                21057 non-null  float64
#  6   reason                      21057 non-null  object
#  7   created_at                  21057 non-null  datetime64[ns, UTC]
#  8   updated_at                  21057 non-null  datetime64[ns, UTC]
#  9   paid_at                     15438 non-null  datetime64[ns, UTC]
#  10  from_date                   6749 non-null   datetime64[ns, UTC]
#  11  to_date                     6512 non-null   datetime64[ns, UTC]
#  12  charge_moment               21057 non-null  object
#  13  amount                      21057 non-null  float64
#  14  cash_request_status         21057 non-null  object
#  15  cash_request_created_at     21057 non-null  datetime64[ns, UTC]
#  16  cash_request_updated_at     21057 non-null  datetime64[ns, UTC]
#  17  user_id                     20151 non-null  float64
#  18  moderated_at                11115 non-null  datetime64[ns, UTC]
#  19  deleted_account_id          906 non-null    float64
#  20  reimbursement_date          18766 non-null  datetime64[ns, UTC]
#  21  cash_request_received_date  19763 non-null  datetime64[ns]
#  22  money_back_date             4943 non-null   datetime64[ns, UTC]
#  23  transfer_type               21057 non-null  object
#  24  send_at                     17282 non-null  datetime64[ns, UTC]
#  25  recovery_status             6894 non-null   object
#  26  reco_creation               6894 non-null   datetime64[ns, UTC]
#  27  reco_last_update            6894 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](13), datetime64[ns](1), float64(4), int64(2), object(8)
# memory usage: 4.5+ MB
